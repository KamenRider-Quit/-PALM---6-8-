# %% [markdown]
# **本次比赛整体方案参考AIStuidio用户“红白黑”的项目“常规赛：PALM病理性近视预测基线方案”。<br>项目地址：
# [常规赛：PALM病理性近视预测基线](https://aistudio.baidu.com/aistudio/projectdetail/1968869?channelType=0&channel=0)**

# %% [markdown]
# # 0.赛题简介：
# ```
# PALM病理性近视预测常规赛的重点是研究和发展与病理性近视诊断相关的算法。该常规赛的目标是评估和比较在一个常见的视网膜眼底图像数据集上检测病理性近视的自动算法。具体任务是将提供的图像分为病理性近视眼底彩照和非病理性近视眼底彩照，其中，非病理性近视眼底彩照包括正常眼底和高度近视眼底彩照。
# ```
# ![](https://ai-studio-static-online.cdn.bcebos.com/debda405c1d149d5974909f6e5f69d15643c9cab5fc74c4fbbf29c6115e839a0)
#
# ---
# 题干提到，该比赛的目标是“将提供的图像分为病理性、非病理性彩照”，其中非病理性数据有两类，均标记为“非病理性”。本质上来说，可以将赛题理解为一个二分类任务。

# %% [markdown]
# # 1.导入开发套件PaddleCLas
# * 若无法从GitHub上顺利导入套件，可从码云导入。

# %%
# !git clone https://github.com/PaddlePaddle/PaddleClas.git
# !git clone https://gitee.com/paddlepaddle/PaddleClas.git -b develop

# %% [markdown]
# * 解压数据集，并将其放入PaddleClas的dataset文件夹中

# %%
# !cd /home/aistudio/

# !unzip -oq /home/aistudio/data/data93287/常规赛：PALM病理性近视预测.zip
# !mv 常规赛：PALM病理性近视预测 PaddleClas/dataset/
# !rm -rf PaddleClas/dataset/__MACOSX
# Out:
# rm: cannot remove '__MACOSX': Is a directory

# %% [markdown]
# # 2.数据集处理
#
# * PALM病理性近视预测常规赛由中山大学中山眼科中心提供800张带病理性近视分类标注的眼底彩照供选手训练模型，另提供400张带标注数据供平台进行模型测试
# * Train文件夹中包含fundus_image文件夹和Classification.xlsx文件。其中fundus_image文件夹存放训练集，Classification.xlsx文件中为各眼底图像是否属于病理性近视，属于为1，不属于为0
# * PALM-Testing400-Images 文件夹包含测试集文件，共400张眼底彩照，命名形如T0001.jpg。

# %% [markdown]
# * 从训练集中划分出一部分数据作为验证集，len(训练集：验证集) = 8：2

# %%
import pandas as pd
import os
from tqdm import tqdm

random_seed = 1024

Image_path = 'Train/fundus_image'                             # 数据集存放路径
total_data = pd.read_excel('PaddleClas/dataset/常规赛：PALM病理性近视预测/Train/Classification.xlsx')       # 读取数据集label文件，xlsx格式

for i in range(len(total_data)):                                                         # 将DataFrame表格中的图片补足路径
    total_data.iloc[i, 0] = os.path.join(Image_path, total_data.iloc[i, 0])              # 拼接路径

total_data = total_data.sample(frac=1.0, random_state=random_seed).reset_index(drop=True)       # frac=1.0对应随机采样全部样本（表格数据），对应打乱表格


# 训练集：验证集占比设定
train_percent = 0.8

train_data = total_data.to_numpy()[:int(len(total_data) * train_percent)] # 要保存的训练数据
eval_data = total_data.to_numpy()[int(len(total_data) * train_percent):]  # 要保存的验证数据

train_txt_save_path = 'PaddleClas/dataset/常规赛：PALM病理性近视预测/train_list.txt' # 训练集label文件存放路径
val_txt_save_path = 'PaddleClas/dataset/常规赛：PALM病理性近视预测/val_list.txt' # 验证集label文件存放路径

with open(train_txt_save_path, 'w') as f:
    t_tq = tqdm(train_data)
    t_tq.set_description('Train Data Spliting')
    for i in t_tq:
        f.write(i[0]+' '+str(i[1])+'\n')

with open(val_txt_save_path, 'w') as f:
    v_tq = tqdm(eval_data)
    v_tq.set_description('Val Data Spliting')
    for i in v_tq:
        f.write(i[0]+' '+str(i[1])+'\n')
# Out:
# Train Data Spliting: 100%|██████████| 640/640 [00:00<00:00, 337824.64it/s]
# Val Data Spliting: 100%|██████████| 160/160 [00:00<00:00, 137602.76it/s]

# %%
# 查看数据集大小

print('length of training data: ', len(train_data))
print('length of eval_data: ', len(eval_data))
# Out:
# length of training data:  640
# length of eval_data:  160

# %% [markdown]
# # 4.模型选择
# 模型选用：DeiTDeiT_base_distilled_patch16_384。<br>
# 其配置文件路径：PaddleClas/configs/DeiT/DeiT_base_distilled_patch16_384.yaml

# %%
# 以下为更改后的yaml文件内容
# 若需修改配置，将其更改后替换原yaml文件内容

'''
mode: 'train'
ARCHITECTURE:
    name: 'DeiT_base_distilled_patch16_384'

# 预训练模型：本项目默认不使用预训练模型
pretrained_model: ""
model_save_dir: "./output/"  # 模型训练参数结果存放路径

classes_num: 2       # 修改分类数，本次任务为2分类

total_images:800        # 修改数据集大小 
save_interval: 1        # 模型参数保存频率：
validate: True          # 是否开启评估
valid_interval: 1       # 评估频率
epochs: 120             # 总训练轮数
topk: 2                 # 
image_shape: [3, 384, 384]

use_mix: False
ls_epsilon: -1

# 学习率设定
LEARNING_RATE:
    function: 'Cosine'          
    params:                   
        lr: 0.01               

# 优化器设定
OPTIMIZER:
    function: 'Momentum'
    params:
        momentum: 0.9
    regularizer:
        function: 'L2'   # L2正则化
        factor: 0.000100


# 浅谈num_workers参数：
# dataloader一次性创建num_worker个worker;
# 也可以说dataloader一次性创建num_worker个工作进程，worker也是普通的工作进程，
# 并用batch_sampler将指定batch分配给指定worker，worker将它负责的batch加载进RAM。

# num_worker设置得大，好处是寻batch速度快，因为下一轮迭代的batch很可能在上一轮/上上一轮...迭代时已经加载好了；
# 坏处是内存开销大，也加重了CPU负担。

# 如果num_worker设为0，意味着每一轮迭代时，dataloader不再有自主加载数据到RAM这一步骤（因为没有worker了），
# 而是在RAM中找batch，找不到时再加载相应的batch。缺点当然是速度更慢。
num_workers的设定，取决于运行环境的硬件配置是否吃得消，尤其是内存；这里参数为PaddleClas里默认给出的4。


# 训练策略配置
TRAIN:
    batch_size: 64                                                 # 数据读取批次大小
    num_workers: 4
    file_list: "./dataset/常规赛：PALM病理性近视预测/train_list.txt" # 训练数据label文件路径
    data_dir: "./dataset/常规赛：PALM病理性近视预测/"                # 训练集数据路径
    shuffle_seed: 0
    transforms:                                                    # transform设定：数据增强方案
        - DecodeImage:             # 图像解码
            to_rgb: True
            channel_first: False
        - RandCropImage:           # 随机裁剪
            size: 384
        - RandFlipImage:           # 随机翻转
            flip_code: 1
        - NormalizeImage:          # 图像数值标准化
            scale: 1./255.
            mean: [0.485, 0.456, 0.406]
            std: [0.229, 0.224, 0.225]
            order: ''
        - ToCHWImage:

# 验证策略设定
VALID:
    batch_size: 64
    num_workers: 4
    file_list: "./dataset/常规赛：PALM病理性近视预测/val_list.txt" # 验证数据label文件路径
    data_dir: "./dataset/常规赛：PALM病理性近视预测/"              # 验证集数据路径
    shuffle_seed: 0
    transforms:
        - DecodeImage:
            to_rgb: True
            channel_first: False
        - ResizeImage:            # 图像尺寸变形
            resize_short: 426
        - CropImage:              # 图像裁剪
            size: 384
        - NormalizeImage:
            scale: 1.0/255.0
            mean: [0.485, 0.456, 0.406]
            std: [0.229, 0.224, 0.225]
            order: ''
        - ToCHWImage:

'''

# %% [markdown]
# # 5.模型训练
# * 使用tools/train.py进行训练
# * 参数列表：<br>
# -c 'yaml配置文件路径'<br>
# -o '预训练模型路径，不使用则不填'<br>
# -o '是否使用GPU'

# %%
# %cd /home/aistudio/PaddleClas

# !python tools/train.py \
    -c configs/DeiT/DeiT_base_distilled_patch16_384.yaml \
    -o use_gpu=True

# %% [markdown]
# # 6.模型预测
# PaddleClas在tools中给出infer.py文件进行预测，更改后可直接生成csv文件用于提交。

# %%
# 预测文件infer_V2.py内容

'''
import numpy as np
import cv2
import os
import sys

import paddle
import paddle.nn.functional as F

__dir__ = os.path.dirname(os.path.abspath(__file__))
sys.path.append(__dir__)
sys.path.append(os.path.abspath(os.path.join(__dir__, '../..')))

from ppcls.utils.save_load import load_dygraph_pretrain
from ppcls.utils import logger
from ppcls.modeling import architectures
from utils import parse_args, get_image_list, preprocess, postprocess, save_prelabel_results


def main():
    args = parse_args()
    # assign the place
    place = paddle.set_device('gpu' if args.use_gpu else 'cpu')
    multilabel = True if args.multilabel else False

    net = architectures.__dict__[args.model](class_dim=args.class_num)
    load_dygraph_pretrain(net, args.pretrained_model, args.load_static_weights)
    image_list = get_image_list(args.image_file)
    batch_input_list = []
    img_path_list = []
    cnt = 0

    # 添加结果列表，保存预测结果**********************
    submit_list = []
    # *********************************************
    id_info = 0  # 计数
    for idx, img_path in enumerate(image_list):
        img = cv2.imread(img_path)
        if img is None:
            logger.warning(
                "Image file failed to read and has been skipped. The path: {}".
                format(img_path))
            continue
        else:
            img = img[:, :, ::-1]
            data = preprocess(img, args)
            batch_input_list.append(data)
            img_path_list.append(img_path)
            cnt += 1

        if cnt % args.batch_size == 0 or (idx + 1) == len(image_list):
            batch_tensor = paddle.to_tensor(batch_input_list)
            net.eval()
            batch_outputs = net(batch_tensor)
            if args.model == "GoogLeNet":
                batch_outputs = batch_outputs[0]
            if multilabel:
                batch_outputs = F.sigmoid(batch_outputs)
            else:
                batch_outputs = F.softmax(batch_outputs)
            batch_outputs = batch_outputs.numpy()
            batch_result_list = postprocess(batch_outputs, args.top_k, multilabel=multilabel)

            for number, result_dict in enumerate(batch_result_list):
                filename = img_path_list[number].split("/")[-1]
                clas_ids = result_dict["clas_ids"]
                id_info += 1
                if multilabel:
                    print("File:{}, multilabel result: ".format(filename))
                    for id, score in zip(clas_ids, result_dict["scores"]):
                        print("\tclass id: {}, probability: {:.2f}".format(id, score))
                else:
                    scores_str = "[{}]".format(", ".join("{:.2f}".format(
                        r) for r in result_dict["scores"]))
                    print("Id:{}, File:{}, Top-{} result: class id(s): {}, score(s): {}".
                        format(id_info, filename, args.top_k, clas_ids, scores_str))

                    # 保存提交文件 -- 保存病理的结果********************
                    submit_list.append([filename, float(clas_ids[0])])  # 加入当前预测结果
                    # *********************************************
                    print(filename, float(clas_ids[0]))

                if args.pre_label_image:
                    save_prelabel_results(clas_ids[0], img_path_list[number],
                                          args.pre_label_out_idr)

            batch_input_list = []
            img_path_list = []
    # 转换数据类型 *********************************
    submit_list = np.asarray(submit_list)

    import pandas as pd
    Submit_data = pd.DataFrame(submit_list)          # 转为DataFrame格式
    Submit_data.columns = ['FileName', 'PM Risk']    # 修改列名
    Submit_data = Submit_data.sort_values(by='FileName').reset_index(drop=True)   # 按照图片id排列
    Submit_data.to_csv('Classification_Results.csv', index=False, float_format="%.1f")       # 保存结果csv
    # *********************************************


if __name__ == "__main__":
    main()
'''

# %%
# 将文件移入infer文件夹中

# !cp infer_V2.py PaddleClas/tools/infer/

# %% [markdown]
# 参数说明：<br>
# * --model：模型名称，此处选用DeiT_base_distilled_patch16_384
# * --i：训练集路径
# * --pretrained_model：模型权重文件路径。使用之前训练好的模型进行预测。
# * --use_gpu：是否使用GPU
# * --class_num：分类数目。本次任务为二分类任务，class_num - 2
# * --resize_short：对输入图像进行等比例缩放，表示最短边的尺寸；默认值256
# * --resize: 对resize_short操作后的进行居中裁剪，表示裁剪的尺寸；默认值224
# * --pre_label_image : 是否对图像数据进行预标注，默认值False
# * pre_label_out_idr : 预标注图像数据的输出文件夹，当pre_label_image=True时，会在该文件夹下面生成很多个子文件夹，每个文件夹名称为类别id，其中存储模型预测**属于该类别的所有图像。**（适用于多分类任务的数据划分）

# %%
# !cd /home/aistudio/PaddleClas/

# !python PaddleClas/tools/infer/infer_V2.py \
    --model DeiT_base_distilled_patch16_384 \
    -i PaddleClas/dataset/常规赛：PALM病理性近视预测/PALM-Testing400-Images \
    --pretrained_model PaddleClas/output/DeiT_base_distilled_patch16_384/best_model/ppcls  \
    --use_gpu True\
    --class_num 2 \
    --resize_short=426 \
    --resize=384
# Out:
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/layers/utils.py:26: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   def convert_to_list(value, n, name, dtype=np.int):
# W0704 22:53:11.062652   192 device_context.cc:362] Please NOTE: device: 0, GPU Compute Capability: 7.0, Driver API Version: 10.1, Runtime API Version: 10.1
# W0704 22:53:11.067523   192 device_context.cc:372] device: 0, cuDNN Version: 7.6.
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/tensor/creation.py:143: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   if data.dtype == np.object:
# Id:1, File:T0242.jpg, Top-1 result: class id(s): [1], score(s): [0.97]
# T0242.jpg 1.0
# Id:2, File:T0078.jpg, Top-1 result: class id(s): [0], score(s): [0.99]
# T0078.jpg 0.0
# Id:3, File:T0085.jpg, Top-1 result: class id(s): [1], score(s): [1.00]
# T0085.jpg 1.0
# Id:4, File:T0004.jpg, Top-1 result: class id(s): [1], score(s): [0.92]
# T0004.jpg 1.0
# Id:5, File:T0129.jpg, Top-1 result: class id(s): [0], score(s): [0.98]
# T0129.jpg 0.0
# Id:6, File:T0303.jpg, Top-1 result: class id(s): [1], score(s): [0.50]
# T0303.jpg 1.0
# Id:7, File:T0355.jpg, Top-1 result: class id(s): [0], score(s): [0.75]
# T0355.jpg 0.0
# Id:8, File:T0103.jpg, Top-1 result: class id(s): [0], score(s): [0.94]
# T0103.jpg 0.0
# Id:9, File:T0206.jpg, Top-1 result: class id(s): [1], score(s): [0.85]
# T0206.jpg 1.0
# Id:10, File:T0260.jpg, Top-1 result: class id(s): [1], score(s): [0.76]
# T0260.jpg 1.0
# Id:11, File:T0327.jpg, Top-1 result: class id(s): [1], score(s): [0.99]
# T0327.jpg 1.0
# Id:12, File:T0282.jpg, Top-1 result: class id(s): [1], score(s): [0.99]
# T0282.jpg 1.0
# Id:13, File:T0158.jpg, Top-1 result: class id(s): [1], score(s): [0.56]
# T0158.jpg 1.0
# Id:14, File:T0236.jpg, Top-1 result: class id(s): [1], score(s): [0.85]
# T0236.jpg 1.0
# Id:15, File:T0345.jpg, Top-1 result: class id(s): [1], score(s): [0.80]
# T0345.jpg 1.0
# Id:16, File:T0316.jpg, Top-1 result: class id(s): [0], score(s): [0.94]
# T0316.jpg 0.0
# Id:17, File:T0322.jpg, Top-1 result: class id(s): [0], score(s): [0.95]
# T0322.jpg 0.0
# Id:18, File:T0346.jpg, Top-1 result: class id(s): [1], score(s): [0.98]
# T0346.jpg 1.0
# Id:19, File:T0087.jpg, Top-1 result: class id(s): [1], score(s): [1.00]
# T0087.jpg 1.0
# Id:20, File:T0389.jpg, Top-1 result: class id(s): [0], score(s): [0.82]
# T0389.jpg 0.0
# Id:21, File:T0106.jpg, Top-1 result: class id(s): [1], score(s): [0.75]
# T0106.jpg 1.0
# Id:22, File:T0159.jpg, Top-1 result: class id(s): [1], score(s): [1.00]
# T0159.jpg 1.0
# Id:23, File:T0342.jpg, Top-1 result: class id(s): [1], score(s): [0.92]
# T0342.jpg 1.0
# Id:24, File:T0112.jpg, Top-1 result: class id(s): [0], score(s): [1.00]
# T0112.jpg 0.0
# Id:25, File:T0273.jpg, Top-1 result: class id(s): [1], score(s): [0.98]
# T0273.jpg 1.0
# Id:26, File:T0088.jpg, Top-1 result: class id(s): [1], score(s): [0.98]
# T0088.jpg 1.0
# Id:27, File:T0301.jpg, Top-1 result: class id(s): [0], score(s): [1.00]
# T0301.jpg 0.0
# Id:28, File:T0104.jpg, Top-1 result: class id(s): [0], score(s): [1.00]
# T0104.jpg 0.0
# Id:29, File:T0149.jpg, Top-1 result: class id(s): [0], score(s): [1.00]
# T0149.jpg 0.0
# Id:30, File:T0246.jpg, Top-1 result: class id(s): [1], score(s): [0.99]
# T0246.jpg 1.0
# Id:31, File:T0285.jpg, Top-1 result: class id(s): [0], score(s): [0.81]
# T0285.jpg 0.0
# Id:32, File:T0174.jpg, Top-1 result: class id(s): [1], score(s): [0.99]
# T0174.jpg 1.0
# Id:33, File:T0238.jpg, Top-1 result: class id(s): [1], score(s): [0.84]
# T0238.jpg 1.0
# Id:34, File:T0250.jpg, Top-1 result: class id(s): [1], score(s): [1.00]
# T0250.jpg 1.0
# Id:35, File:T0071.jpg, Top-1 result: class id(s): [1], score(s): [0.83]
# T0071.jpg 1.0
# Id:36, File:T0397.jpg, Top-1 result: class id(s): [1], score(s): [0.86]
# T0397.jpg 1.0
# Id:37, File:T0392.jpg, Top-1 result: class id(s): [1], score(s): [0.95]
# T0392.jpg 1.0
# Id:38, File:T0138.jpg, Top-1 result: class id(s): [0], score(s): [0.90]
# T0138.jpg 0.0
# Id:39, File:T0184.jpg, Top-1 result: class id(s): [0], score(s): [0.99]
# T0184.jpg 0.0
# Id:40, File:T0154.jpg, Top-1 result: class id(s): [1], score(s): [0.94]
# T0154.jpg 1.0
# Id:41, File:T0048.jpg, Top-1 result: class id(s): [0], score(s): [0.99]
# T0048.jpg 0.0
# Id:42, File:T0203.jpg, Top-1 result: class id(s): [1], score(s): [1.00]
# T0203.jpg 1.0
# Id:43, File:T0358.jpg, Top-1 result: class id(s): [0], score(s): [1.00]
# T0358.jpg 0.0
# Id:44, File:T0396.jpg, Top-1 result: class id(s): [1], score(s): [1.00]
# T0396.jpg 1.0
# Id:45, File:T0108.jpg, Top-1 result: class id(s): [0], score(s): [1.00]
# T0108.jpg 0.0
# Id:46, File:T0367.jpg, Top-1 result: class id(s): [1], score(s): [0.94]
# T0367.jpg 1.0
# Id:47, File:T0243.jpg, Top-1 result: class id(s): [0], score(s): [0.97]
# T0243.jpg 0.0
# Id:48, File:T0270.jpg, Top-1 result: class id(s): [1], score(s): [0.97]
# T0270.jpg 1.0
# Id:49, File:T0182.jpg, Top-1 result: class id(s): [1], score(s): [0.99]
# T0182.jpg 1.0
# Id:50, File:T0386.jpg, Top-1 result: class id(s): [0], score(s): [0.99]
# T0386.jpg 0.0
# Id:51, File:T0040.jpg, Top-1 result: class id(s): [0], score(s): [0.86]
# T0040.jpg 0.0
# Id:52, File:T0271.jpg, Top-1 result: class id(s): [1], score(s): [1.00]
# T0271.jpg 1.0
# Id:53, File:T0261.jpg, Top-1 result: class id(s): [1], score(s): [0.98]
# T0261.jpg 1.0
# Id:54, File:T0348.jpg, Top-1 result: class id(s): [0], score(s): [0.92]
# T0348.jpg 0.0
# Id:55, File:T0241.jpg, Top-1 result: class id(s): [1], score(s): [0.99]
# T0241.jpg 1.0
# Id:56, File:T0199.jpg, Top-1 result: class id(s): [0], score(s): [0.98]
# T0199.jpg 0.0
# Id:57, File:T0225.jpg, Top-1 result: class id(s): [1], score(s): [0.86]
# T0225.jpg 1.0
# Id:58, File:T0151.jpg, Top-1 result: class id(s): [1], score(s): [0.97]
# T0151.jpg 1.0
# Id:59, File:T0254.jpg, Top-1 result: class id(s): [0], score(s): [1.00]
# T0254.jpg 0.0
# Id:60, File:T0200.jpg, Top-1 result: class id(s): [0], score(s): [0.99]
# T0200.jpg 0.0
# Id:61, File:T0218.jpg, Top-1 result: class id(s): [1], score(s): [0.94]
# T0218.jpg 1.0
# Id:62, File:T0120.jpg, Top-1 result: class id(s): [0], score(s): [0.83]
# T0120.jpg 0.0
# Id:63, File:T0278.jpg, Top-1 result: class id(s): [1], score(s): [1.00]
# T0278.jpg 1.0
# Id:64, File:T0272.jpg, Top-1 result: class id(s): [1], score(s): [1.00]
# T0272.jpg 1.0
# Id:65, File:T0069.jpg, Top-1 result: class id(s): [1], score(s): [0.98]
# T0069.jpg 1.0
# Id:66, File:T0016.jpg, Top-1 result: class id(s): [0], score(s): [1.00]
# T0016.jpg 0.0
# Id:67, File:T0060.jpg, Top-1 result: class id(s): [0], score(s): [0.97]
# T0060.jpg 0.0
# Id:68, File:T0169.jpg, Top-1 result: class id(s): [0], score(s): [1.00]
# T0169.jpg 0.0
# Id:69, File:T0066.jpg, Top-1 result: class id(s): [1], score(s): [1.00]
# T0066.jpg 1.0
# Id:70, File:T0308.jpg, Top-1 result: class id(s): [0], score(s): [0.95]
# T0308.jpg 0.0
# Id:71, File:T0030.jpg, Top-1 result: class id(s): [0], score(s): [0.90]
# T0030.jpg 0.0
# Id:72, File:T0194.jpg, Top-1 result: class id(s): [1], score(s): [1.00]
# T0194.jpg 1.0
# Id:73, File:T0175.jpg, Top-1 result: class id(s): [1], score(s): [0.99]
# T0175.jpg 1.0
# Id:74, File:T0214.jpg, Top-1 result: class id(s): [0], score(s): [0.99]
# T0214.jpg 0.0
# Id:75, File:T0374.jpg, Top-1 result: class id(s): [1], score(s): [0.85]
# T0374.jpg 1.0
# Id:76, File:T0245.jpg, Top-1 result: class id(s): [0], score(s): [1.00]
# T0245.jpg 0.0
# Id:77, File:T0135.jpg, Top-1 result: class id(s): [0], score(s): [0.89]
# T0135.jpg 0.0
# Id:78, File:T0148.jpg, Top-1 result: class id(s): [1], score(s): [1.00]
# T0148.jpg 1.0
# Id:79, File:T0205.jpg, Top-1 result: class id(s): [0], score(s): [0.97]
# T0205.jpg 0.0
# Id:80, File:T0057.jpg, Top-1 result: class id(s): [0], score(s): [0.98]
# T0057.jpg 0.0
# Id:81, File:T0252.jpg, Top-1 result: class id(s): [0], score(s): [0.69]
# T0252.jpg 0.0
# Id:82, File:T0361.jpg, Top-1 result: class id(s): [0], score(s): [1.00]
# T0361.jpg 0.0
# Id:83, File:T0022.jpg, Top-1 result: class id(s): [0], score(s): [1.00]
# T0022.jpg 0.0
# Id:84, File:T0018.jpg, Top-1 result: class id(s): [1], score(s): [1.00]
# T0018.jpg 1.0
# Id:85, File:T0314.jpg, Top-1 result: class id(s): [1], score(s): [0.99]
# T0314.jpg 1.0
# Id:86, File:T0079.jpg, Top-1 result: class id(s): [1], score(s): [1.00]
# T0079.jpg 1.0
# Id:87, File:T0228.jpg, Top-1 result: class id(s): [0], score(s): [1.00]
# T0228.jpg 0.0
# Id:88, File:T0093.jpg, Top-1 result: class id(s): [0], score(s): [0.99]
# T0093.jpg 0.0
# Id:89, File:T0226.jpg, Top-1 result: class id(s): [0], score(s): [0.94]
# T0226.jpg 0.0
# Id:90, File:T0105.jpg, Top-1 result: class id(s): [1], score(s): [0.99]
# T0105.jpg 1.0
# Id:91, File:T0383.jpg, Top-1 result: class id(s): [0], score(s): [0.70]
# T0383.jpg 0.0
# Id:92, File:T0090.jpg, Top-1 result: class id(s): [0], score(s): [0.96]
# T0090.jpg 0.0
# Id:93, File:T0286.jpg, Top-1 result: class id(s): [0], score(s): [0.72]
# T0286.jpg 0.0
# Id:94, File:T0191.jpg, Top-1 result: class id(s): [1], score(s): [0.80]
# T0191.jpg 1.0
# Id:95, File:T0210.jpg, Top-1 result: class id(s): [1], score(s): [0.88]
# T0210.jpg 1.0
# Id:96, File:T0177.jpg, Top-1 result: class id(s): [1], score(s): [1.00]
# T0177.jpg 1.0
# Id:97, File:T0262.jpg, Top-1 result: class id(s): [0], score(s): [0.96]
# T0262.jpg 0.0
# Id:98, File:T0213.jpg, Top-1 result: class id(s): [1], score(s): [1.00]
# T0213.jpg 1.0
# Id:99, File:T0333.jpg, Top-1 result: class id(s): [0], score(s): [0.99]
# T0333.jpg 0.0
# Id:100, File:T0053.jpg, Top-1 result: class id(s): [0], score(s): [0.97]
# T0053.jpg 0.0
# Id:101, File:T0291.jpg, Top-1 result: class id(s): [0], score(s): [0.93]
# T0291.jpg 0.0
# Id:102, File:T0173.jpg, Top-1 result: class id(s): [1], score(s): [0.98]
# T0173.jpg 1.0
# Id:103, File:T0128.jpg, Top-1 result: class id(s): [0], score(s): [0.99]
# T0128.jpg 0.0
# Id:104, File:T0222.jpg, Top-1 result: class id(s): [1], score(s): [0.99]
# T0222.jpg 1.0
# Id:105, File:T0114.jpg, Top-1 result: class id(s): [1], score(s): [0.99]
# T0114.jpg 1.0
# Id:106, File:T0123.jpg, Top-1 result: class id(s): [1], score(s): [0.75]
# T0123.jpg 1.0
# Id:107, File:T0395.jpg, Top-1 result: class id(s): [1], score(s): [0.87]
# T0395.jpg 1.0
# Id:108, File:T0343.jpg, Top-1 result: class id(s): [0], score(s): [0.99]
# T0343.jpg 0.0
# Id:109, File:T0258.jpg, Top-1 result: class id(s): [0], score(s): [0.99]
# T0258.jpg 0.0
# Id:110, File:T0309.jpg, Top-1 result: class id(s): [0], score(s): [0.99]
# T0309.jpg 0.0
# Id:111, File:T0081.jpg, Top-1 result: class id(s): [1], score(s): [0.87]
# T0081.jpg 1.0
# Id:112, File:T0354.jpg, Top-1 result: class id(s): [1], score(s): [0.94]
# T0354.jpg 1.0
# Id:113, File:T0298.jpg, Top-1 result: class id(s): [0], score(s): [1.00]
# T0298.jpg 0.0
# Id:114, File:T0237.jpg, Top-1 result: class id(s): [0], score(s): [0.93]
# T0237.jpg 0.0
# Id:115, File:T0201.jpg, Top-1 result: class id(s): [1], score(s): [1.00]
# T0201.jpg 1.0
# Id:116, File:T0288.jpg, Top-1 result: class id(s): [1], score(s): [1.00]
# T0288.jpg 1.0
# Id:117, File:T0277.jpg, Top-1 result: class id(s): [0], score(s): [0.88]
# T0277.jpg 0.0
# Id:118, File:T0180.jpg, Top-1 result: class id(s): [0], score(s): [0.62]
# T0180.jpg 0.0
# Id:119, File:T0217.jpg, Top-1 result: class id(s): [0], score(s): [0.56]
# T0217.jpg 0.0
# Id:120, File:T0116.jpg, Top-1 result: class id(s): [1], score(s): [0.93]
# T0116.jpg 1.0
# Id:121, File:T0363.jpg, Top-1 result: class id(s): [0], score(s): [0.98]
# T0363.jpg 0.0
# Id:122, File:T0231.jpg, Top-1 result: class id(s): [1], score(s): [1.00]
# T0231.jpg 1.0
# Id:123, File:T0311.jpg, Top-1 result: class id(s): [1], score(s): [1.00]
# T0311.jpg 1.0
# Id:124, File:T0223.jpg, Top-1 result: class id(s): [1], score(s): [1.00]
# T0223.jpg 1.0
# Id:125, File:T0359.jpg, Top-1 result: class id(s): [1], score(s): [0.98]
# T0359.jpg 1.0
# Id:126, File:T0336.jpg, Top-1 result: class id(s): [1], score(s): [0.85]
# T0336.jpg 1.0
# Id:127, File:T0038.jpg, Top-1 result: class id(s): [1], score(s): [0.95]
# T0038.jpg 1.0
# Id:128, File:T0215.jpg, Top-1 result: class id(s): [0], score(s): [1.00]
# T0215.jpg 0.0
# Id:129, File:T0306.jpg, Top-1 result: class id(s): [1], score(s): [1.00]
# T0306.jpg 1.0
# Id:130, File:T0137.jpg, Top-1 result: class id(s): [1], score(s): [0.67]
# T0137.jpg 1.0
# Id:131, File:T0376.jpg, Top-1 result: class id(s): [0], score(s): [0.98]
# T0376.jpg 0.0
# Id:132, File:T0232.jpg, Top-1 result: class id(s): [1], score(s): [0.97]
# T0232.jpg 1.0
# Id:133, File:T0313.jpg, Top-1 result: class id(s): [0], score(s): [0.97]
# T0313.jpg 0.0
# Id:134, File:T0015.jpg, Top-1 result: class id(s): [1], score(s): [0.99]
# T0015.jpg 1.0
# Id:135, File:T0098.jpg, Top-1 result: class id(s): [0], score(s): [0.93]
# T0098.jpg 0.0
# Id:136, File:T0364.jpg, Top-1 result: class id(s): [1], score(s): [1.00]
# T0364.jpg 1.0
# Id:137, File:T0021.jpg, Top-1 result: class id(s): [0], score(s): [0.57]
# T0021.jpg 0.0
# Id:138, File:T0349.jpg, Top-1 result: class id(s): [1], score(s): [0.87]
# T0349.jpg 1.0
# Id:139, File:T0370.jpg, Top-1 result: class id(s): [1], score(s): [0.94]
# T0370.jpg 1.0
# Id:140, File:T0058.jpg, Top-1 result: class id(s): [1], score(s): [0.88]
# T0058.jpg 1.0
# Id:141, File:T0068.jpg, Top-1 result: class id(s): [0], score(s): [0.98]
# T0068.jpg 0.0
# Id:142, File:T0113.jpg, Top-1 result: class id(s): [1], score(s): [1.00]
# T0113.jpg 1.0
# Id:143, File:T0054.jpg, Top-1 result: class id(s): [1], score(s): [0.99]
# T0054.jpg 1.0
# Id:144, File:T0125.jpg, Top-1 result: class id(s): [0], score(s): [0.98]
# T0125.jpg 0.0
# Id:145, File:T0263.jpg, Top-1 result: class id(s): [1], score(s): [1.00]
# T0263.jpg 1.0
# Id:146, File:T0378.jpg, Top-1 result: class id(s): [1], score(s): [1.00]
# T0378.jpg 1.0
# Id:147, File:T0156.jpg, Top-1 result: class id(s): [0], score(s): [0.99]
# T0156.jpg 0.0
# Id:148, File:T0097.jpg, Top-1 result: class id(s): [1], score(s): [0.96]
# T0097.jpg 1.0
# Id:149, File:T0202.jpg, Top-1 result: class id(s): [0], score(s): [1.00]
# T0202.jpg 0.0
# Id:150, File:T0063.jpg, Top-1 result: class id(s): [0], score(s): [0.96]
# T0063.jpg 0.0
# Id:151, File:T0240.jpg, Top-1 result: class id(s): [1], score(s): [0.99]
# T0240.jpg 1.0
# Id:152, File:T0275.jpg, Top-1 result: class id(s): [1], score(s): [0.60]
# T0275.jpg 1.0
# Id:153, File:T0110.jpg, Top-1 result: class id(s): [1], score(s): [1.00]
# T0110.jpg 1.0
# Id:154, File:T0284.jpg, Top-1 result: class id(s): [0], score(s): [1.00]
# T0284.jpg 0.0
# Id:155, File:T0067.jpg, Top-1 result: class id(s): [1], score(s): [1.00]
# T0067.jpg 1.0
# Id:156, File:T0037.jpg, Top-1 result: class id(s): [1], score(s): [0.99]
# T0037.jpg 1.0
# Id:157, File:T0083.jpg, Top-1 result: class id(s): [0], score(s): [0.99]
# T0083.jpg 0.0
# Id:158, File:T0290.jpg, Top-1 result: class id(s): [0], score(s): [1.00]
# T0290.jpg 0.0
# Id:159, File:T0171.jpg, Top-1 result: class id(s): [0], score(s): [0.99]
# T0171.jpg 0.0
# Id:160, File:T0279.jpg, Top-1 result: class id(s): [1], score(s): [0.99]
# T0279.jpg 1.0
# Id:161, File:T0234.jpg, Top-1 result: class id(s): [0], score(s): [0.81]
# T0234.jpg 0.0
# Id:162, File:T0198.jpg, Top-1 result: class id(s): [1], score(s): [1.00]
# T0198.jpg 1.0
# Id:163, File:T0076.jpg, Top-1 result: class id(s): [0], score(s): [0.98]
# T0076.jpg 0.0
# Id:164, File:T0052.jpg, Top-1 result: class id(s): [0], score(s): [0.97]
# T0052.jpg 0.0
# Id:165, File:T0357.jpg, Top-1 result: class id(s): [0], score(s): [1.00]
# T0357.jpg 0.0
# Id:166, File:T0393.jpg, Top-1 result: class id(s): [1], score(s): [0.98]
# T0393.jpg 1.0
# Id:167, File:T0074.jpg, Top-1 result: class id(s): [1], score(s): [0.99]
# T0074.jpg 1.0
# Id:168, File:T0107.jpg, Top-1 result: class id(s): [1], score(s): [1.00]
# T0107.jpg 1.0
# Id:169, File:T0141.jpg, Top-1 result: class id(s): [1], score(s): [0.97]
# T0141.jpg 1.0
# Id:170, File:T0080.jpg, Top-1 result: class id(s): [1], score(s): [0.99]
# T0080.jpg 1.0
# Id:171, File:T0020.jpg, Top-1 result: class id(s): [1], score(s): [0.94]
# T0020.jpg 1.0
# Id:172, File:T0373.jpg, Top-1 result: class id(s): [1], score(s): [0.93]
# T0373.jpg 1.0
# Id:173, File:T0007.jpg, Top-1 result: class id(s): [1], score(s): [0.99]
# T0007.jpg 1.0
# Id:174, File:T0011.jpg, Top-1 result: class id(s): [0], score(s): [0.52]
# T0011.jpg 0.0
# Id:175, File:T0117.jpg, Top-1 result: class id(s): [0], score(s): [0.87]
# T0117.jpg 0.0
# Id:176, File:T0391.jpg, Top-1 result: class id(s): [0], score(s): [0.53]
# T0391.jpg 0.0
# Id:177, File:T0347.jpg, Top-1 result: class id(s): [1], score(s): [0.99]
# T0347.jpg 1.0
# Id:178, File:T0356.jpg, Top-1 result: class id(s): [1], score(s): [1.00]
# T0356.jpg 1.0
# Id:179, File:T0369.jpg, Top-1 result: class id(s): [1], score(s): [0.98]
# T0369.jpg 1.0
# Id:180, File:T0059.jpg, Top-1 result: class id(s): [1], score(s): [1.00]
# T0059.jpg 1.0
# Id:181, File:T0224.jpg, Top-1 result: class id(s): [0], score(s): [0.98]
# T0224.jpg 0.0
# Id:182, File:T0323.jpg, Top-1 result: class id(s): [0], score(s): [0.97]
# T0323.jpg 0.0
# Id:183, File:T0042.jpg, Top-1 result: class id(s): [0], score(s): [0.99]
# T0042.jpg 0.0
# Id:184, File:T0124.jpg, Top-1 result: class id(s): [1], score(s): [1.00]
# T0124.jpg 1.0
# Id:185, File:T0187.jpg, Top-1 result: class id(s): [0], score(s): [1.00]
# T0187.jpg 0.0
# Id:186, File:T0220.jpg, Top-1 result: class id(s): [0], score(s): [0.98]
# T0220.jpg 0.0
# Id:187, File:T0143.jpg, Top-1 result: class id(s): [1], score(s): [0.99]
# T0143.jpg 1.0
# Id:188, File:T0041.jpg, Top-1 result: class id(s): [1], score(s): [0.99]
# T0041.jpg 1.0
# Id:189, File:T0382.jpg, Top-1 result: class id(s): [0], score(s): [0.99]
# T0382.jpg 0.0
# Id:190, File:T0168.jpg, Top-1 result: class id(s): [0], score(s): [1.00]
# T0168.jpg 0.0
# Id:191, File:T0229.jpg, Top-1 result: class id(s): [0], score(s): [0.99]
# T0229.jpg 0.0
# Id:192, File:T0043.jpg, Top-1 result: class id(s): [1], score(s): [1.00]
# T0043.jpg 1.0
# Id:193, File:T0122.jpg, Top-1 result: class id(s): [1], score(s): [1.00]
# T0122.jpg 1.0
# Id:194, File:T0321.jpg, Top-1 result: class id(s): [1], score(s): [1.00]
# T0321.jpg 1.0
# Id:195, File:T0006.jpg, Top-1 result: class id(s): [0], score(s): [0.77]
# T0006.jpg 0.0
# Id:196, File:T0051.jpg, Top-1 result: class id(s): [1], score(s): [1.00]
# T0051.jpg 1.0
# Id:197, File:T0344.jpg, Top-1 result: class id(s): [1], score(s): [0.99]
# T0344.jpg 1.0
# Id:198, File:T0253.jpg, Top-1 result: class id(s): [1], score(s): [0.67]
# T0253.jpg 1.0
# Id:199, File:T0330.jpg, Top-1 result: class id(s): [0], score(s): [1.00]
# T0330.jpg 0.0
# Id:200, File:T0044.jpg, Top-1 result: class id(s): [0], score(s): [0.96]
# T0044.jpg 0.0
# Id:201, File:T0134.jpg, Top-1 result: class id(s): [1], score(s): [0.99]
# T0134.jpg 1.0
# Id:202, File:T0121.jpg, Top-1 result: class id(s): [0], score(s): [1.00]
# T0121.jpg 0.0
# Id:203, File:T0255.jpg, Top-1 result: class id(s): [0], score(s): [1.00]
# T0255.jpg 0.0
# Id:204, File:T0045.jpg, Top-1 result: class id(s): [0], score(s): [0.99]
# T0045.jpg 0.0
# Id:205, File:T0339.jpg, Top-1 result: class id(s): [0], score(s): [0.99]
# T0339.jpg 0.0
# Id:206, File:T0295.jpg, Top-1 result: class id(s): [0], score(s): [1.00]
# T0295.jpg 0.0
# Id:207, File:T0380.jpg, Top-1 result: class id(s): [1], score(s): [0.99]
# T0380.jpg 1.0
# Id:208, File:T0183.jpg, Top-1 result: class id(s): [1], score(s): [0.99]
# T0183.jpg 1.0
# Id:209, File:T0267.jpg, Top-1 result: class id(s): [0], score(s): [0.99]
# T0267.jpg 0.0
# Id:210, File:T0398.jpg, Top-1 result: class id(s): [1], score(s): [0.99]
# T0398.jpg 1.0
# Id:211, File:T0031.jpg, Top-1 result: class id(s): [0], score(s): [0.91]
# T0031.jpg 0.0
# Id:212, File:T0017.jpg, Top-1 result: class id(s): [0], score(s): [0.99]
# T0017.jpg 0.0
# Id:213, File:T0192.jpg, Top-1 result: class id(s): [0], score(s): [0.98]
# T0192.jpg 0.0
# Id:214, File:T0230.jpg, Top-1 result: class id(s): [0], score(s): [0.68]
# T0230.jpg 0.0
# Id:215, File:T0089.jpg, Top-1 result: class id(s): [0], score(s): [0.97]
# T0089.jpg 0.0
# Id:216, File:T0195.jpg, Top-1 result: class id(s): [0], score(s): [0.94]
# T0195.jpg 0.0
# Id:217, File:T0384.jpg, Top-1 result: class id(s): [0], score(s): [1.00]
# T0384.jpg 0.0
# Id:218, File:T0181.jpg, Top-1 result: class id(s): [1], score(s): [1.00]
# T0181.jpg 1.0
# Id:219, File:T0092.jpg, Top-1 result: class id(s): [1], score(s): [0.99]
# T0092.jpg 1.0
# Id:220, File:T0304.jpg, Top-1 result: class id(s): [0], score(s): [0.96]
# T0304.jpg 0.0
# Id:221, File:T0025.jpg, Top-1 result: class id(s): [0], score(s): [1.00]
# T0025.jpg 0.0
# Id:222, File:T0142.jpg, Top-1 result: class id(s): [1], score(s): [0.90]
# T0142.jpg 1.0
# Id:223, File:T0111.jpg, Top-1 result: class id(s): [1], score(s): [0.89]
# T0111.jpg 1.0
# Id:224, File:T0188.jpg, Top-1 result: class id(s): [1], score(s): [0.92]
# T0188.jpg 1.0
# Id:225, File:T0152.jpg, Top-1 result: class id(s): [1], score(s): [0.81]
# T0152.jpg 1.0
# Id:226, File:T0340.jpg, Top-1 result: class id(s): [1], score(s): [1.00]
# T0340.jpg 1.0
# Id:227, File:T0280.jpg, Top-1 result: class id(s): [0], score(s): [1.00]
# T0280.jpg 0.0
# Id:228, File:T0119.jpg, Top-1 result: class id(s): [0], score(s): [0.97]
# T0119.jpg 0.0
# Id:229, File:T0023.jpg, Top-1 result: class id(s): [1], score(s): [0.98]
# T0023.jpg 1.0
# Id:230, File:T0034.jpg, Top-1 result: class id(s): [1], score(s): [0.98]
# T0034.jpg 1.0
# Id:231, File:T0072.jpg, Top-1 result: class id(s): [1], score(s): [0.98]
# T0072.jpg 1.0
# Id:232, File:T0259.jpg, Top-1 result: class id(s): [0], score(s): [0.98]
# T0259.jpg 0.0
# Id:233, File:T0332.jpg, Top-1 result: class id(s): [1], score(s): [0.99]
# T0332.jpg 1.0
# Id:234, File:T0140.jpg, Top-1 result: class id(s): [1], score(s): [0.67]
# T0140.jpg 1.0
# Id:235, File:T0299.jpg, Top-1 result: class id(s): [1], score(s): [1.00]
# T0299.jpg 1.0
# Id:236, File:T0185.jpg, Top-1 result: class id(s): [0], score(s): [0.87]
# T0185.jpg 0.0
# Id:237, File:T0379.jpg, Top-1 result: class id(s): [0], score(s): [0.60]
# T0379.jpg 0.0
# Id:238, File:T0082.jpg, Top-1 result: class id(s): [1], score(s): [1.00]
# T0082.jpg 1.0
# Id:239, File:T0289.jpg, Top-1 result: class id(s): [0], score(s): [0.55]
# T0289.jpg 0.0
# Id:240, File:T0265.jpg, Top-1 result: class id(s): [0], score(s): [1.00]
# T0265.jpg 0.0
# Id:241, File:T0035.jpg, Top-1 result: class id(s): [1], score(s): [0.98]
# T0035.jpg 1.0
# Id:242, File:T0341.jpg, Top-1 result: class id(s): [1], score(s): [0.99]
# T0341.jpg 1.0
# Id:243, File:T0310.jpg, Top-1 result: class id(s): [0], score(s): [0.97]
# T0310.jpg 0.0
# Id:244, File:T0329.jpg, Top-1 result: class id(s): [1], score(s): [0.98]
# T0329.jpg 1.0
# Id:245, File:T0219.jpg, Top-1 result: class id(s): [1], score(s): [0.51]
# T0219.jpg 1.0
# Id:246, File:T0328.jpg, Top-1 result: class id(s): [0], score(s): [1.00]
# T0328.jpg 0.0
# Id:247, File:T0046.jpg, Top-1 result: class id(s): [0], score(s): [0.99]
# T0046.jpg 0.0
# Id:248, File:T0381.jpg, Top-1 result: class id(s): [0], score(s): [1.00]
# T0381.jpg 0.0
# Id:249, File:T0305.jpg, Top-1 result: class id(s): [0], score(s): [1.00]
# T0305.jpg 0.0
# Id:250, File:T0161.jpg, Top-1 result: class id(s): [0], score(s): [0.98]
# T0161.jpg 0.0
# Id:251, File:T0166.jpg, Top-1 result: class id(s): [1], score(s): [0.90]
# T0166.jpg 1.0
# Id:252, File:T0204.jpg, Top-1 result: class id(s): [0], score(s): [0.96]
# T0204.jpg 0.0
# Id:253, File:T0126.jpg, Top-1 result: class id(s): [1], score(s): [0.85]
# T0126.jpg 1.0
# Id:254, File:T0244.jpg, Top-1 result: class id(s): [1], score(s): [1.00]
# T0244.jpg 1.0
# Id:255, File:T0027.jpg, Top-1 result: class id(s): [0], score(s): [0.91]
# T0027.jpg 0.0
# Id:256, File:T0338.jpg, Top-1 result: class id(s): [1], score(s): [0.98]
# T0338.jpg 1.0
# Id:257, File:T0178.jpg, Top-1 result: class id(s): [1], score(s): [1.00]
# T0178.jpg 1.0
# Id:258, File:T0179.jpg, Top-1 result: class id(s): [0], score(s): [1.00]
# T0179.jpg 0.0
# Id:259, File:T0005.jpg, Top-1 result: class id(s): [1], score(s): [1.00]
# T0005.jpg 1.0
# Id:260, File:T0387.jpg, Top-1 result: class id(s): [1], score(s): [0.98]
# T0387.jpg 1.0
# Id:261, File:T0164.jpg, Top-1 result: class id(s): [0], score(s): [0.96]
# T0164.jpg 0.0
# Id:262, File:T0153.jpg, Top-1 result: class id(s): [1], score(s): [0.93]
# T0153.jpg 1.0
# Id:263, File:T0095.jpg, Top-1 result: class id(s): [0], score(s): [0.99]
# T0095.jpg 0.0
# Id:264, File:T0133.jpg, Top-1 result: class id(s): [1], score(s): [1.00]
# T0133.jpg 1.0
# Id:265, File:T0064.jpg, Top-1 result: class id(s): [1], score(s): [0.88]
# T0064.jpg 1.0
# Id:266, File:T0324.jpg, Top-1 result: class id(s): [0], score(s): [0.89]
# T0324.jpg 0.0
# Id:267, File:T0145.jpg, Top-1 result: class id(s): [1], score(s): [0.99]
# T0145.jpg 1.0
# Id:268, File:T0296.jpg, Top-1 result: class id(s): [0], score(s): [1.00]
# T0296.jpg 0.0
# Id:269, File:T0132.jpg, Top-1 result: class id(s): [0], score(s): [0.54]
# T0132.jpg 0.0
# Id:270, File:T0211.jpg, Top-1 result: class id(s): [1], score(s): [1.00]
# T0211.jpg 1.0
# Id:271, File:T0010.jpg, Top-1 result: class id(s): [1], score(s): [0.99]
# T0010.jpg 1.0
# Id:272, File:T0366.jpg, Top-1 result: class id(s): [0], score(s): [0.63]
# T0366.jpg 0.0
# Id:273, File:T0131.jpg, Top-1 result: class id(s): [1], score(s): [1.00]
# T0131.jpg 1.0
# Id:274, File:T0036.jpg, Top-1 result: class id(s): [1], score(s): [0.99]
# T0036.jpg 1.0
# Id:275, File:T0375.jpg, Top-1 result: class id(s): [1], score(s): [0.99]
# T0375.jpg 1.0
# Id:276, File:T0377.jpg, Top-1 result: class id(s): [0], score(s): [0.91]
# T0377.jpg 0.0
# Id:277, File:T0365.jpg, Top-1 result: class id(s): [0], score(s): [0.99]
# T0365.jpg 0.0
# Id:278, File:T0165.jpg, Top-1 result: class id(s): [0], score(s): [1.00]
# T0165.jpg 0.0
# Id:279, File:T0368.jpg, Top-1 result: class id(s): [0], score(s): [0.57]
# T0368.jpg 0.0
# Id:280, File:T0139.jpg, Top-1 result: class id(s): [1], score(s): [1.00]
# T0139.jpg 1.0
# Id:281, File:T0118.jpg, Top-1 result: class id(s): [0], score(s): [0.95]
# T0118.jpg 0.0
# Id:282, File:T0162.jpg, Top-1 result: class id(s): [0], score(s): [0.99]
# T0162.jpg 0.0
# Id:283, File:T0099.jpg, Top-1 result: class id(s): [0], score(s): [1.00]
# T0099.jpg 0.0
# Id:284, File:T0331.jpg, Top-1 result: class id(s): [0], score(s): [1.00]
# T0331.jpg 0.0
# Id:285, File:T0049.jpg, Top-1 result: class id(s): [0], score(s): [1.00]
# T0049.jpg 0.0
# Id:286, File:T0019.jpg, Top-1 result: class id(s): [0], score(s): [1.00]
# T0019.jpg 0.0
# Id:287, File:T0337.jpg, Top-1 result: class id(s): [0], score(s): [0.98]
# T0337.jpg 0.0
# Id:288, File:T0094.jpg, Top-1 result: class id(s): [0], score(s): [0.52]
# T0094.jpg 0.0
# Id:289, File:T0084.jpg, Top-1 result: class id(s): [0], score(s): [1.00]
# T0084.jpg 0.0
# Id:290, File:T0300.jpg, Top-1 result: class id(s): [1], score(s): [0.97]
# T0300.jpg 1.0
# Id:291, File:T0029.jpg, Top-1 result: class id(s): [1], score(s): [0.68]
# T0029.jpg 1.0
# Id:292, File:T0061.jpg, Top-1 result: class id(s): [1], score(s): [0.96]
# T0061.jpg 1.0
# Id:293, File:T0013.jpg, Top-1 result: class id(s): [1], score(s): [1.00]
# T0013.jpg 1.0
# Id:294, File:T0334.jpg, Top-1 result: class id(s): [0], score(s): [0.94]
# T0334.jpg 0.0
# Id:295, File:T0100.jpg, Top-1 result: class id(s): [0], score(s): [0.85]
# T0100.jpg 0.0
# Id:296, File:T0212.jpg, Top-1 result: class id(s): [0], score(s): [0.98]
# T0212.jpg 0.0
# Id:297, File:T0315.jpg, Top-1 result: class id(s): [1], score(s): [0.99]
# T0315.jpg 1.0
# Id:298, File:T0281.jpg, Top-1 result: class id(s): [0], score(s): [1.00]
# T0281.jpg 0.0
# Id:299, File:T0256.jpg, Top-1 result: class id(s): [1], score(s): [1.00]
# T0256.jpg 1.0
# Id:300, File:T0287.jpg, Top-1 result: class id(s): [0], score(s): [0.97]
# T0287.jpg 0.0
# Id:301, File:T0176.jpg, Top-1 result: class id(s): [1], score(s): [1.00]
# T0176.jpg 1.0
# Id:302, File:T0160.jpg, Top-1 result: class id(s): [1], score(s): [1.00]
# T0160.jpg 1.0
# Id:303, File:T0196.jpg, Top-1 result: class id(s): [1], score(s): [1.00]
# T0196.jpg 1.0
# Id:304, File:T0130.jpg, Top-1 result: class id(s): [1], score(s): [0.99]
# T0130.jpg 1.0
# Id:305, File:T0325.jpg, Top-1 result: class id(s): [1], score(s): [0.99]
# T0325.jpg 1.0
# Id:306, File:T0167.jpg, Top-1 result: class id(s): [1], score(s): [1.00]
# T0167.jpg 1.0
# Id:307, File:T0247.jpg, Top-1 result: class id(s): [0], score(s): [1.00]
# T0247.jpg 0.0
# Id:308, File:T0320.jpg, Top-1 result: class id(s): [1], score(s): [0.98]
# T0320.jpg 1.0
# Id:309, File:T0317.jpg, Top-1 result: class id(s): [1], score(s): [0.74]
# T0317.jpg 1.0
# Id:310, File:T0070.jpg, Top-1 result: class id(s): [0], score(s): [1.00]
# T0070.jpg 0.0
# Id:311, File:T0268.jpg, Top-1 result: class id(s): [1], score(s): [1.00]
# T0268.jpg 1.0
# Id:312, File:T0002.jpg, Top-1 result: class id(s): [0], score(s): [0.99]
# T0002.jpg 0.0
# Id:313, File:T0115.jpg, Top-1 result: class id(s): [1], score(s): [1.00]
# T0115.jpg 1.0
# Id:314, File:T0276.jpg, Top-1 result: class id(s): [1], score(s): [1.00]
# T0276.jpg 1.0
# Id:315, File:T0001.jpg, Top-1 result: class id(s): [1], score(s): [0.98]
# T0001.jpg 1.0
# Id:316, File:T0189.jpg, Top-1 result: class id(s): [0], score(s): [0.90]
# T0189.jpg 0.0
# Id:317, File:T0235.jpg, Top-1 result: class id(s): [1], score(s): [0.71]
# T0235.jpg 1.0
# Id:318, File:T0351.jpg, Top-1 result: class id(s): [1], score(s): [0.99]
# T0351.jpg 1.0
# Id:319, File:T0009.jpg, Top-1 result: class id(s): [1], score(s): [0.98]
# T0009.jpg 1.0
# Id:320, File:T0233.jpg, Top-1 result: class id(s): [1], score(s): [0.54]
# T0233.jpg 1.0
# Id:321, File:T0197.jpg, Top-1 result: class id(s): [0], score(s): [0.97]
# T0197.jpg 0.0
# Id:322, File:T0371.jpg, Top-1 result: class id(s): [1], score(s): [1.00]
# T0371.jpg 1.0
# Id:323, File:T0249.jpg, Top-1 result: class id(s): [0], score(s): [0.72]
# T0249.jpg 0.0
# Id:324, File:T0307.jpg, Top-1 result: class id(s): [0], score(s): [0.96]
# T0307.jpg 0.0
# Id:325, File:T0248.jpg, Top-1 result: class id(s): [0], score(s): [0.94]
# T0248.jpg 0.0
# Id:326, File:T0318.jpg, Top-1 result: class id(s): [0], score(s): [0.84]
# T0318.jpg 0.0
# Id:327, File:T0264.jpg, Top-1 result: class id(s): [1], score(s): [0.99]
# T0264.jpg 1.0
# Id:328, File:T0394.jpg, Top-1 result: class id(s): [1], score(s): [0.99]
# T0394.jpg 1.0
# Id:329, File:T0146.jpg, Top-1 result: class id(s): [0], score(s): [0.96]
# T0146.jpg 0.0
# Id:330, File:T0208.jpg, Top-1 result: class id(s): [1], score(s): [0.96]
# T0208.jpg 1.0
# Id:331, File:T0101.jpg, Top-1 result: class id(s): [1], score(s): [0.93]
# T0101.jpg 1.0
# Id:332, File:T0157.jpg, Top-1 result: class id(s): [0], score(s): [0.99]
# T0157.jpg 0.0
# Id:333, File:T0109.jpg, Top-1 result: class id(s): [1], score(s): [0.99]
# T0109.jpg 1.0
# Id:334, File:T0239.jpg, Top-1 result: class id(s): [1], score(s): [0.89]
# T0239.jpg 1.0
# Id:335, File:T0388.jpg, Top-1 result: class id(s): [1], score(s): [1.00]
# T0388.jpg 1.0
# Id:336, File:T0209.jpg, Top-1 result: class id(s): [1], score(s): [0.93]
# T0209.jpg 1.0
# Id:337, File:T0390.jpg, Top-1 result: class id(s): [0], score(s): [0.98]
# T0390.jpg 0.0
# Id:338, File:T0008.jpg, Top-1 result: class id(s): [1], score(s): [1.00]
# T0008.jpg 1.0
# Id:339, File:T0096.jpg, Top-1 result: class id(s): [0], score(s): [0.97]
# T0096.jpg 0.0
# Id:340, File:T0028.jpg, Top-1 result: class id(s): [0], score(s): [0.97]
# T0028.jpg 0.0
# Id:341, File:T0216.jpg, Top-1 result: class id(s): [0], score(s): [0.99]
# T0216.jpg 0.0
# Id:342, File:T0302.jpg, Top-1 result: class id(s): [0], score(s): [0.99]
# T0302.jpg 0.0
# Id:343, File:T0024.jpg, Top-1 result: class id(s): [0], score(s): [0.53]
# T0024.jpg 0.0
# Id:344, File:T0293.jpg, Top-1 result: class id(s): [0], score(s): [0.94]
# T0293.jpg 0.0
# Id:345, File:T0026.jpg, Top-1 result: class id(s): [1], score(s): [1.00]
# T0026.jpg 1.0
# Id:346, File:T0012.jpg, Top-1 result: class id(s): [1], score(s): [1.00]
# T0012.jpg 1.0
# Id:347, File:T0221.jpg, Top-1 result: class id(s): [1], score(s): [1.00]
# T0221.jpg 1.0
# Id:348, File:T0091.jpg, Top-1 result: class id(s): [1], score(s): [1.00]
# T0091.jpg 1.0
# Id:349, File:T0190.jpg, Top-1 result: class id(s): [1], score(s): [0.95]
# T0190.jpg 1.0
# Id:350, File:T0353.jpg, Top-1 result: class id(s): [1], score(s): [1.00]
# T0353.jpg 1.0
# Id:351, File:T0073.jpg, Top-1 result: class id(s): [1], score(s): [0.98]
# T0073.jpg 1.0
# Id:352, File:T0127.jpg, Top-1 result: class id(s): [1], score(s): [1.00]
# T0127.jpg 1.0
# Id:353, File:T0102.jpg, Top-1 result: class id(s): [1], score(s): [1.00]
# T0102.jpg 1.0
# Id:354, File:T0319.jpg, Top-1 result: class id(s): [1], score(s): [0.99]
# T0319.jpg 1.0
# Id:355, File:T0155.jpg, Top-1 result: class id(s): [1], score(s): [1.00]
# T0155.jpg 1.0
# Id:356, File:T0294.jpg, Top-1 result: class id(s): [0], score(s): [0.99]
# T0294.jpg 0.0
# Id:357, File:T0163.jpg, Top-1 result: class id(s): [0], score(s): [0.96]
# T0163.jpg 0.0
# Id:358, File:T0269.jpg, Top-1 result: class id(s): [0], score(s): [0.95]
# T0269.jpg 0.0
# Id:359, File:T0297.jpg, Top-1 result: class id(s): [0], score(s): [0.72]
# T0297.jpg 0.0
# Id:360, File:T0144.jpg, Top-1 result: class id(s): [0], score(s): [0.99]
# T0144.jpg 0.0
# Id:361, File:T0003.jpg, Top-1 result: class id(s): [0], score(s): [0.99]
# T0003.jpg 0.0
# Id:362, File:T0032.jpg, Top-1 result: class id(s): [0], score(s): [0.98]
# T0032.jpg 0.0
# Id:363, File:T0014.jpg, Top-1 result: class id(s): [1], score(s): [0.91]
# T0014.jpg 1.0
# Id:364, File:T0039.jpg, Top-1 result: class id(s): [0], score(s): [0.99]
# T0039.jpg 0.0
# Id:365, File:T0251.jpg, Top-1 result: class id(s): [1], score(s): [0.96]
# T0251.jpg 1.0
# Id:366, File:T0075.jpg, Top-1 result: class id(s): [1], score(s): [0.99]
# T0075.jpg 1.0
# Id:367, File:T0312.jpg, Top-1 result: class id(s): [1], score(s): [1.00]
# T0312.jpg 1.0
# Id:368, File:T0266.jpg, Top-1 result: class id(s): [1], score(s): [0.98]
# T0266.jpg 1.0
# Id:369, File:T0362.jpg, Top-1 result: class id(s): [0], score(s): [0.99]
# T0362.jpg 0.0
# Id:370, File:T0086.jpg, Top-1 result: class id(s): [1], score(s): [1.00]
# T0086.jpg 1.0
# Id:371, File:T0400.jpg, Top-1 result: class id(s): [1], score(s): [0.98]
# T0400.jpg 1.0
# Id:372, File:T0136.jpg, Top-1 result: class id(s): [1], score(s): [1.00]
# T0136.jpg 1.0
# Id:373, File:T0172.jpg, Top-1 result: class id(s): [1], score(s): [0.99]
# T0172.jpg 1.0
# Id:374, File:T0062.jpg, Top-1 result: class id(s): [0], score(s): [0.71]
# T0062.jpg 0.0
# Id:375, File:T0372.jpg, Top-1 result: class id(s): [1], score(s): [1.00]
# T0372.jpg 1.0
# Id:376, File:T0326.jpg, Top-1 result: class id(s): [1], score(s): [0.98]
# T0326.jpg 1.0
# Id:377, File:T0335.jpg, Top-1 result: class id(s): [0], score(s): [1.00]
# T0335.jpg 0.0
# Id:378, File:T0257.jpg, Top-1 result: class id(s): [0], score(s): [0.97]
# T0257.jpg 0.0
# Id:379, File:T0360.jpg, Top-1 result: class id(s): [1], score(s): [0.90]
# T0360.jpg 1.0
# Id:380, File:T0065.jpg, Top-1 result: class id(s): [1], score(s): [0.86]
# T0065.jpg 1.0
# Id:381, File:T0352.jpg, Top-1 result: class id(s): [1], score(s): [0.95]
# T0352.jpg 1.0
# Id:382, File:T0227.jpg, Top-1 result: class id(s): [1], score(s): [0.99]
# T0227.jpg 1.0
# Id:383, File:T0150.jpg, Top-1 result: class id(s): [1], score(s): [0.88]
# T0150.jpg 1.0
# Id:384, File:T0399.jpg, Top-1 result: class id(s): [0], score(s): [0.96]
# T0399.jpg 0.0
# Id:385, File:T0283.jpg, Top-1 result: class id(s): [0], score(s): [1.00]
# T0283.jpg 0.0
# Id:386, File:T0050.jpg, Top-1 result: class id(s): [1], score(s): [0.98]
# T0050.jpg 1.0
# Id:387, File:T0047.jpg, Top-1 result: class id(s): [0], score(s): [1.00]
# T0047.jpg 0.0
# Id:388, File:T0033.jpg, Top-1 result: class id(s): [0], score(s): [0.99]
# T0033.jpg 0.0
# Id:389, File:T0274.jpg, Top-1 result: class id(s): [0], score(s): [1.00]
# T0274.jpg 0.0
# Id:390, File:T0147.jpg, Top-1 result: class id(s): [0], score(s): [1.00]
# T0147.jpg 0.0
# Id:391, File:T0385.jpg, Top-1 result: class id(s): [0], score(s): [0.99]
# T0385.jpg 0.0
# Id:392, File:T0292.jpg, Top-1 result: class id(s): [0], score(s): [0.90]
# T0292.jpg 0.0
# Id:393, File:T0056.jpg, Top-1 result: class id(s): [1], score(s): [0.62]
# T0056.jpg 1.0
# Id:394, File:T0055.jpg, Top-1 result: class id(s): [1], score(s): [1.00]
# T0055.jpg 1.0
# Id:395, File:T0077.jpg, Top-1 result: class id(s): [0], score(s): [0.99]
# T0077.jpg 0.0
# Id:396, File:T0207.jpg, Top-1 result: class id(s): [1], score(s): [0.99]
# T0207.jpg 1.0
# Id:397, File:T0186.jpg, Top-1 result: class id(s): [0], score(s): [0.98]
# T0186.jpg 0.0
# Id:398, File:T0193.jpg, Top-1 result: class id(s): [0], score(s): [0.99]
# T0193.jpg 0.0
# Id:399, File:T0170.jpg, Top-1 result: class id(s): [1], score(s): [1.00]
# T0170.jpg 1.0
# Id:400, File:T0350.jpg, Top-1 result: class id(s): [1], score(s): [0.94]
# T0350.jpg 1.0

# %% [markdown]
# # 7.提交结果
# 执行完预测程序后，会在跟目录生成结果csv文件，可用于比赛结果提交。
